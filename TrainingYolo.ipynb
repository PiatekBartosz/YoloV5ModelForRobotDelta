# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Get YoloV5 repo

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# !pip install -U -r yolov5/requirements.txt
# !cd yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# Requirement already satisfied: gitpython in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: ipython in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (8.10.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 8)) (1.24.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (4.7.0.68)
# Requirement already satisfied: Pillow>=7.1.2 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (9.4.0)
# Requirement already satisfied: psutil in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (5.9.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (2.28.2)
# Requirement already satisfied: scipy>=1.4.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 14)) (1.10.1)
# Requirement already satisfied: thop>=0.1.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (0.1.1.post2209072238)
# Requirement already satisfied: tqdm>=4.64.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 18)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 22)) (2.12.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 42)) (67.3.2)
# Requirement already satisfied: wheel>=0.38.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 43)) (0.38.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from gitpython->-r yolov5/requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: pygments>=2.4.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (2.14.0)
# Requirement already satisfied: pexpect>4.3 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: stack-data in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: decorator in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: backcall in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pickleshare in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from ipython->-r yolov5/requirements.txt (line 6)) (3.0.36)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/bartek/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bartek/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/bartek/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bartek/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/bartek/.local/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 7)) (21.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bartek/.local/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 13)) (1.26.14)
# Requirement already satisfied: torch in /home/bartek/.local/lib/python3.10/site-packages (from thop>=0.1.1->-r yolov5/requirements.txt (line 15)) (1.13.1+cu116)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (2.16.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (2.2.3)
# Requirement already satisfied: grpcio>=1.48.2 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.51.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: protobuf>=3.19.6 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (4.22.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /home/bartek/.local/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.8.1)
# Requirement already satisfied: pytz>=2020.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2022.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython->-r yolov5/requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from jedi>=0.16->ipython->-r yolov5/requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from pexpect>4.3->ipython->-r yolov5/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->-r yolov5/requirements.txt (line 6)) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (2.1.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: pure-eval in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: typing-extensions in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from torch->thop>=0.1.1->-r yolov5/requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 22)) (3.2.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python yolov5/train.py -h
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--imgsz IMGSZ]
#                 [--rect] [--resume [RESUME]] [--nosave] [--noval]
#                 [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--bucket BUCKET] [--cache [CACHE]] [--image-weights]
#                 [--device DEVICE] [--multi-scale] [--single-cls]
#                 [--optimizer {SGD,Adam,AdamW}] [--sync-bn] [--workers WORKERS]
#                 [--project PROJECT] [--name NAME] [--exist-ok] [--quad]
#                 [--cos-lr] [--label-smoothing LABEL_SMOOTHING]
#                 [--patience PATIENCE] [--freeze FREEZE [FREEZE ...]]
#                 [--save-period SAVE_PERIOD] [--seed SEED]
#                 [--local_rank LOCAL_RANK] [--entity ENTITY]
#                 [--upload_dataset [UPLOAD_DATASET]]
#                 [--bbox_interval BBOX_INTERVAL]
#                 [--artifact_alias ARTIFACT_ALIAS]
#
# options:
#   -h, --help            show this help message and exit
#   --weights WEIGHTS     initial weights path
#   --cfg CFG             model.yaml path
#   --data DATA           dataset.yaml path
#   --hyp HYP             hyperparameters path
#   --epochs EPOCHS       total training epochs
#   --batch-size BATCH_SIZE
#                         total batch size for all GPUs, -1 for autobatch
#   --imgsz IMGSZ, --img IMGSZ, --img-size IMGSZ
#                         train, val image size (pixels)
#   --rect                rectangular training
#   --resume [RESUME]     resume most recent training
#   --nosave              only save final checkpoint
#   --noval               only validate final epoch
#   --noautoanchor        disable AutoAnchor
#   --noplots             save no plot files
#   --evolve [EVOLVE]     evolve hyperparameters for x generations
#   --bucket BUCKET       gsutil bucket
#   --cache [CACHE]       image --cache ram/disk
#   --image-weights       use weighted image selection for training
#   --device DEVICE       cuda device, i.e. 0 or 0,1,2,3 or cpu
#   --multi-scale         vary img-size +/- 50%
#   --single-cls          train multi-class data as single-class
#   --optimizer {SGD,Adam,AdamW}
#                         optimizer
#   --sync-bn             use SyncBatchNorm, only available in DDP mode
#   --workers WORKERS     max dataloader workers (per RANK in DDP mode)
#   --project PROJECT     save to project/name
#   --name NAME           save to project/name
#   --exist-ok            existing project/name ok, do not increment
#   --quad                quad dataloader
#   --cos-lr              cosine LR scheduler
#   --label-smoothing LABEL_SMOOTHING
#                         Label smoothing epsilon
#   --patience PATIENCE   EarlyStopping patience (epochs without improvement)
#   --freeze FREEZE [FREEZE ...]
#                         Freeze layers: backbone=10, first3=0 1 2
#   --save-period SAVE_PERIOD
#                         Save checkpoint every x epochs (disabled if < 1)
#   --seed SEED           Global training seed
#   --local_rank LOCAL_RANK
#                         Automatic DDP Multi-GPU argument, do not modify
#   --entity ENTITY       Entity
#   --upload_dataset [UPLOAD_DATASET]
#                         Upload data, "val" option
#   --bbox_interval BBOX_INTERVAL
#                         Set bounding-box image logging interval
#   --artifact_alias ARTIFACT_ALIAS
#                         Version of dataset artifact to use

# %%
! python yolov5/train.py --img 416 --batch 16 --epochs 300 --data train.yaml --weights yolov5s.pt --device 0
# Out:
# train: weights=yolov5s.pt, cfg=, data=train.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-107-g7a972e8 Python-3.10.9 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3060, 12043MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /home/bartek/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 1.29MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 25.2MB/s]
#
# Overriding model.yaml nc=80 with nc=9
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     37758  models.yolo.Detect                      [9, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7043902 parameters, 7043902 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/da
# train: New cache created: /home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/dataset/labels/train.cache
# val: Scanning /home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/data
# val: New cache created: /home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/dataset/labels/val.cache
#
# AutoAnchor: 5.22 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp4/labels.jpg...
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/exp4
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299      1.57G     0.1069    0.06882    0.06289        164        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702     0.0953      0.184     0.0674     0.0229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      1.57G    0.07184    0.06728    0.05697        102        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.113      0.327       0.11     0.0459
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      1.57G    0.06603    0.06358    0.05155        110        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.218      0.387      0.234     0.0887
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      1.57G    0.05933    0.06065     0.0428        106        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702       0.44      0.548      0.486      0.232
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      1.57G    0.05306    0.05876    0.03599        180        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.452      0.673      0.552      0.307
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      1.57G     0.0486    0.05742    0.03293        109        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.561      0.731      0.622      0.394
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      1.57G    0.04672    0.05489    0.03144        107        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.621      0.746      0.636      0.418
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      1.57G    0.04557    0.05532    0.03036        170        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        200       1702      0.633      0.784      0.669       0.43
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      1.57G    0.04317    0.05176    0.02848        225        416:  ^C
#       8/299      1.57G    0.04317    0.05176    0.02848        225        416:
# Traceback (most recent call last):
#   File "/home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/yolov5/train.py", line 640, in <module>
#     main(opt)
#   File "/home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/yolov5/train.py", line 529, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/yolov5/train.py", line 284, in train
#     for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
#   File "/home/bartek/miniconda3/envs/gpu/lib/python3.10/site-packages/tqdm/std.py", line 1195, in __iter__
#     for obj in iterable:
#   File "/home/bartek/RobotDelta/VisionSystem/YoloV5ModelForRobotDelta/yolov5/utils/dataloaders.py", line 172, in __iter__
#     yield next(self.iterator)
#   File "/home/bartek/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 628, in __next__
#     data = self._next_data()
#   File "/home/bartek/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1316, in _next_data
#     idx, data = self._get_data()
#   File "/home/bartek/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1272, in _get_data
#     success, data = self._try_get_data()
#   File "/home/bartek/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1120, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/home/bartek/miniconda3/envs/gpu/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/home/bartek/miniconda3/envs/gpu/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
